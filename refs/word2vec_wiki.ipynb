# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector
from sklearn.datasets import fetch_20newsgroups
from sklearn.metrics.pairwise import euclidean_distances, cosine_distances

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
    os.makedirs(FLAGS.log_dir)

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
        local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
    statinfo = os.stat(local_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
    return local_filename

filename = maybe_download('text8.zip', 31344016)

# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary


# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 300  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

    # Input data.
    with tf.name_scope('inputs'):
        train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        with tf.name_scope('embeddings'):
            embeddings = tf.Variable(
                  tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
            embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        with tf.name_scope('weights'):
            nce_weights = tf.Variable(
                  tf.truncated_normal(
                  [vocabulary_size, embedding_size],
                  stddev=1.0 / math.sqrt(embedding_size)))
        with tf.name_scope('biases'):
            nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(
            tf.nn.nce_loss(
                weights=nce_weights,
                biases=nce_biases,
                labels=train_labels,
                inputs=embed,
                num_sampled=num_sampled,
                num_classes=vocabulary_size))

    # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)

    # Construct the SGD optimizer using a learning rate of 1.0.
    with tf.name_scope('optimizer'):
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-6-231ed8dc774f>:67: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # Open a writer to write summaries.
    writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                    skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # Define metadata variable.
        run_metadata = tf.RunMetadata()

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
        # Feed metadata variable to session for visualizing the graph in TensorBoard.
        _, summary, loss_val = session.run(
            [optimizer, merged, loss],
            feed_dict=feed_dict,
            run_metadata=run_metadata)
        average_loss += loss_val

        # Add returned summaries to writer in each step.
        writer.add_summary(summary, step)
        # Add metadata to visualize the graph for the last run.
        if step == (num_steps - 1):
            writer.add_run_metadata(run_metadata, 'step%d' % step)

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
                
    final_embeddings = normalized_embeddings.eval()

    # Write corresponding labels for the embeddings.
    with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
        for i in xrange(vocabulary_size):
            f.write(reverse_dictionary[i] + '\n')

    # Save the model for checkpoints.
    saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

    # Create a configuration for visualizing embeddings with the labels in TensorBoard.
    config = projector.ProjectorConfig()
    embedding_conf = config.embeddings.add()
    embedding_conf.tensor_name = embeddings.name
    embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
    projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  281.831787109375
# Nearest to while: classroom, strayed, respects, heterosexuality, recoup, guez, archaeopteryx, hobsbawm,
# Nearest to only: hyginus, coordinate, shaykh, souls, assr, mormon, vocalized, debate,
# Nearest to known: tokelau, fenton, fit, kuwait, malatesta, cdg, unbelievers, candle,
# Nearest to during: doctorow, foy, mem, synthesizers, shamanism, saccharomyces, doctrine, unharmed,
# Nearest to after: might, blockade, nike, larch, narita, ascends, asceticism, bohemia,
# Nearest to more: shorty, resurfaced, futures, mediterranean, michal, backwards, tenerife, contemplation,
# Nearest to see: tetragrammaton, cryptanalyst, lodging, exquisite, jeffers, interdependent, namespaces, unpublished,
# Nearest to into: disadvantaged, tactically, barrel, bouvet, thereafter, subterfuge, lyle, tenths,
# Nearest to with: mri, willis, disintegrating, dazzling, grit, verbal, vaccination, yuma,
# Nearest to six: dever, airwaves, communicates, lodger, casing, exceptions, giuseppe, asgard,
# Nearest to as: cru, benefits, meltdown, murdoc, ericales, fecture, missed, chao,
# Nearest to however: domini, odrade, valiente, gaye, vegetation, shab, nails, sushi,
# Nearest to new: siculus, handset, arno, orcs, fertility, plastics, herbivores, mechanism,
# Nearest to at: duckburg, barnet, backside, pumpkin, graded, precession, methodius, teau,
# Nearest to there: hariri, mcgovern, showroom, namely, jaco, pittsburgh, ciconiiformes, intakes,
# Nearest to s: arbitral, compressible, survive, duarte, checkmate, jezebel, cts, jens,
# Average loss at step  2000 :  112.97827066373826
# Average loss at step  4000 :  52.980012983083725
# Average loss at step  6000 :  33.72549929869175
# Average loss at step  8000 :  23.228003308296202
# Average loss at step  10000 :  17.943782257556915
# Nearest to while: classroom, respects, building, manager, continued, couples, emperor, shrugged,
# Nearest to only: souls, debate, gland, teacher, socialism, coordinate, circle, blair,
# Nearest to known: archie, group, fit, vary, tokelau, anyway, lethbridge, bckgr,
# Nearest to during: in, doctrine, doctorow, phi, isn, track, synthesizers, rockets,
# Nearest to after: blockade, might, and, asceticism, military, in, illyria, external,
# Nearest to more: mediterranean, backwards, also, gland, prosecution, six, zanzibar, contemplation,
# Nearest to see: archie, january, compiled, pro, epidemic, exquisite, inches, trophy,
# Nearest to into: and, thereafter, barrel, to, alien, nine, latin, disadvantaged,
# Nearest to with: in, of, and, is, by, agave, one, vaccination,
# Nearest to six: zero, nine, agave, gland, one, basins, UNK, and,
# Nearest to as: and, in, one, agave, UNK, of, zero, austin,
# Nearest to however: and, of, agave, in, the, addition, volkswagen, jacob,
# Nearest to new: mechanism, around, of, dusk, fertility, tips, von, plastics,
# Nearest to at: in, munich, archie, uke, conquer, nine, byron, decision,
# Nearest to there: namely, defense, pittsburgh, rudolph, thereof, yorktown, users, capable,
# Nearest to s: and, zero, the, of, gland, agave, one, UNK,
# Average loss at step  12000 :  14.020413184285164
# Average loss at step  14000 :  11.89300429224968
# Average loss at step  16000 :  10.162059700489044
# Average loss at step  18000 :  8.49702395617962
# Average loss at step  20000 :  8.179532154679299
# Nearest to while: at, eight, nine, manager, respects, classroom, building, agouti,
# Nearest to only: as, souls, circ, debate, blair, shaykh, circle, gland,
# Nearest to known: archie, fit, group, circ, operatorname, virtuoso, ghana, travelled,
# Nearest to during: in, doctrine, operatorname, doctorow, of, rockets, suebi, isn,
# Nearest to after: in, blockade, and, might, military, asceticism, of, dasyprocta,
# Nearest to more: mediterranean, futures, also, backwards, prescott, prosecution, columnist, a,
# Nearest to see: circ, and, nine, archie, compiled, january, epidemic, exquisite,
# Nearest to into: epistles, and, circ, nine, thereafter, to, by, barrel,
# Nearest to with: in, and, of, by, for, to, is, as,
# Nearest to six: nine, zero, eight, two, one, operatorname, three, four,
# Nearest to as: and, is, in, by, circ, for, UNK, agouti,
# Nearest to however: and, domini, of, UNK, dasyprocta, which, agave, circ,
# Nearest to new: circ, mechanism, herbivores, of, fertility, around, dusk, tips,
# Nearest to at: in, nine, of, and, circ, munich, operatorname, archie,
# Nearest to there: it, and, namely, thereof, defense, pittsburgh, krak, dasyprocta,
# Nearest to s: and, the, zero, of, two, operatorname, his, agouti,
# Average loss at step  22000 :  7.111248805165291
# Average loss at step  24000 :  6.838737618029118
# Average loss at step  26000 :  6.802869163513184
# Average loss at step  28000 :  6.423435767292976
# Average loss at step  30000 :  5.94350799882412
# Nearest to while: at, is, eight, from, respects, manager, tunings, classroom,
# Nearest to only: as, hyginus, nine, souls, circ, debate, circle, it,
# Nearest to known: aba, otimes, archie, circ, operatorname, fit, group, virtuoso,
# Nearest to during: in, of, doctrine, operatorname, doctorow, with, and, by,
# Nearest to after: in, and, blockade, six, four, might, dasyprocta, military,
# Nearest to more: futures, prescott, mediterranean, backwards, prosecution, columnist, also, accountant,
# Nearest to see: circ, and, eight, nine, archie, compiled, feldspar, five,
# Nearest to into: by, from, to, epistles, in, for, and, thereafter,
# Nearest to with: in, by, and, for, seven, of, to, agouti,
# Nearest to six: eight, nine, zero, four, three, two, seven, five,
# Nearest to as: by, and, is, for, circ, in, agouti, UNK,
# Nearest to however: and, trinomial, which, domini, dasyprocta, of, otimes, agave,
# Nearest to new: circ, of, herbivores, mechanism, two, fertility, six, and,
# Nearest to at: in, on, and, by, circ, for, operatorname, nine,
# Nearest to there: it, he, and, zero, sponsors, thereof, four, namely,
# Nearest to s: zero, the, and, of, two, his, five, eight,
# Average loss at step  32000 :  5.991407831192016
# Average loss at step  34000 :  5.710253219485283
# Average loss at step  36000 :  5.748642451763153
# Average loss at step  38000 :  5.5275021461248395
# Average loss at step  40000 :  5.318613144755363
# Nearest to while: at, from, are, in, is, eight, zero, were,
# Nearest to only: hyginus, circ, souls, it, circle, debate, as, dasyprocta,
# Nearest to known: aba, otimes, a, such, circ, fit, operatorname, archie,
# Nearest to during: in, of, doctrine, operatorname, and, doctorow, freight, saccharomyces,
# Nearest to after: in, blockade, five, zero, four, six, and, seven,
# Nearest to more: futures, zero, mediterranean, backwards, prescott, columnist, also, a,
# Nearest to see: zero, circ, and, eight, archie, five, compiled, lodging,
# Nearest to into: from, by, zero, in, nine, epistles, to, prescribed,
# Nearest to with: and, in, by, for, to, zero, from, as,
# Nearest to six: eight, four, zero, seven, three, nine, five, two,
# Nearest to as: by, for, circ, is, agouti, in, and, eight,
# Nearest to however: and, which, domini, trinomial, dasyprocta, or, agave, circ,
# Nearest to new: circ, herbivores, of, mechanism, aba, fertility, arno, tips,
# Nearest to at: in, on, zero, for, circ, from, and, operatorname,
# Nearest to there: it, he, zero, which, they, six, and, thereof,
# Nearest to s: zero, and, the, operatorname, his, of, eight, circ,
# Average loss at step  42000 :  5.389530888199806
# Average loss at step  44000 :  5.2704830373525615
# Average loss at step  46000 :  5.2957877776622775
# Average loss at step  48000 :  5.243134999632836
# Average loss at step  50000 :  5.018155031442642
# Nearest to while: and, from, is, eight, are, at, agouti, six,
# Nearest to only: kapoor, two, it, circ, hyginus, three, franchisee, circle,
# Nearest to known: such, aba, otimes, circ, virtuoso, fit, operatorname, the,
# Nearest to during: in, kapoor, operatorname, three, on, doctrine, and, of,
# Nearest to after: and, six, in, seven, blockade, four, three, as,
# Nearest to more: futures, mediterranean, less, columnist, prescott, circ, backwards, anabaptist,
# Nearest to see: and, circ, seven, eight, archie, lodging, or, four,
# Nearest to into: from, by, to, in, nine, for, epistles, of,
# Nearest to with: in, by, and, for, seven, from, five, as,
# Nearest to six: eight, four, five, three, seven, nine, two, zero,
# Nearest to as: by, for, agouti, eight, and, five, two, is,
# Nearest to however: and, which, dasyprocta, domini, trinomial, circ, that, agave,
# Nearest to new: circ, of, herbivores, six, four, one, mechanism, aba,
# Nearest to at: in, on, four, three, for, operatorname, from, circ,
# Nearest to there: it, he, they, six, kapoor, zero, four, which,
# Nearest to s: of, zero, his, and, the, operatorname, eight, five,
# Average loss at step  52000 :  5.074150531411171
# Average loss at step  54000 :  5.213181106209755
# Average loss at step  56000 :  5.063377937674522
# Average loss at step  58000 :  5.061552039980889
# Average loss at step  60000 :  4.977670649647712
# Nearest to while: is, when, from, and, are, agouti, at, was,
# Nearest to only: kapoor, circ, two, michelob, souls, it, hyginus, seven,
# Nearest to known: such, aba, otimes, circ, virtuoso, kapoor, operatorname, fit,
# Nearest to during: in, kapoor, of, operatorname, with, ursus, on, by,
# Nearest to after: six, in, five, as, four, blockade, three, operatorname,
# Nearest to more: futures, less, circ, a, michelob, other, six, wct,
# Nearest to see: and, circ, seven, eight, four, five, six, archie,
# Nearest to into: from, in, by, to, as, nine, on, prescribed,
# Nearest to with: in, by, and, five, for, from, seven, six,
# Nearest to six: eight, four, seven, nine, five, three, zero, two,
# Nearest to as: by, agouti, is, and, for, five, circ, in,
# Nearest to however: and, which, but, that, circ, or, dasyprocta, four,
# Nearest to new: circ, of, five, six, microsite, and, aba, herbivores,
# Nearest to at: in, michelob, on, five, three, ursus, from, four,
# Nearest to there: it, he, they, zero, kapoor, which, four, six,
# Nearest to s: zero, his, and, operatorname, ursus, five, four, nine,
# Average loss at step  62000 :  5.025796507835389
# Average loss at step  64000 :  4.835840212106705
# Average loss at step  66000 :  4.576818369150161
# Average loss at step  68000 :  5.016755417823791
# Average loss at step  70000 :  4.909472418308258
# Nearest to while: when, from, is, are, was, and, at, agouti,
# Nearest to only: cebus, kapoor, circ, michelob, it, in, ursus, operatorname,
# Nearest to known: such, aba, circ, otimes, well, virtuoso, operatorname, the,
# Nearest to during: in, upanija, and, kapoor, cebus, operatorname, of, ursus,
# Nearest to after: four, in, six, five, was, blockade, as, three,
# Nearest to more: less, futures, most, a, circ, six, wct, ursus,
# Nearest to see: circ, seven, thaler, of, eight, four, three, nine,
# Nearest to into: from, by, nine, to, in, on, as, six,
# Nearest to with: by, and, in, seven, for, from, six, at,
# Nearest to six: eight, four, five, seven, three, nine, two, zero,
# Nearest to as: by, agouti, microcebus, circ, for, cebus, and, in,
# Nearest to however: and, but, which, that, circ, dasyprocta, one, four,
# Nearest to new: circ, of, microcebus, six, microsite, five, aba, herbivores,
# Nearest to at: in, michelob, three, on, ursus, operatorname, five, of,
# Nearest to there: it, he, they, kapoor, microcebus, which, zero, this,
# Nearest to s: his, zero, and, operatorname, of, ursus, two, was,
# Average loss at step  72000 :  4.761187707424164
# Average loss at step  74000 :  4.838093428373337
# Average loss at step  76000 :  4.731106791138649
# Average loss at step  78000 :  4.817783286571503
# Average loss at step  80000 :  4.833156652748585
# Nearest to while: when, from, and, in, although, at, are, was,
# Nearest to only: cebus, kapoor, busan, six, circ, it, michelob, ursus,
# Nearest to known: such, aba, used, circ, otimes, virtuoso, aeronautics, well,
# Nearest to during: in, upanija, kapoor, cebus, operatorname, ursus, by, with,
# Nearest to after: in, five, six, seven, by, four, at, from,
# Nearest to more: less, most, futures, not, circ, cardiomyopathy, wct, ursus,
# Nearest to see: circ, and, seven, thaler, nine, four, ursus, wct,
# Nearest to into: from, by, in, nine, on, to, and, eight,
# Nearest to with: in, by, and, from, of, for, seven, between,
# Nearest to six: five, four, seven, eight, nine, three, two, zero,
# Nearest to as: microcebus, agouti, by, circ, and, cebus, in, for,
# Nearest to however: but, and, which, that, dasyprocta, circ, one, UNK,
# Nearest to new: circ, microcebus, microsite, six, aba, operatorname, herbivores, fertility,
# Nearest to at: in, on, michelob, five, of, from, with, operatorname,
# Nearest to there: it, he, they, which, kapoor, pontificia, six, zero,
# Nearest to s: zero, his, operatorname, nine, four, ursus, and, the,
# Average loss at step  82000 :  4.7704522622823715
# Average loss at step  84000 :  4.7590161743164066
# Average loss at step  86000 :  4.790199075222016
# Average loss at step  88000 :  4.750765005469322
# Average loss at step  90000 :  4.754497849106789
# Nearest to while: when, and, from, although, are, is, were, was,
# Nearest to only: cebus, kapoor, busan, six, circ, michelob, it, ursus,
# Nearest to known: such, aba, used, well, circ, aeronautics, operatorname, otimes,
# Nearest to during: in, upanija, kapoor, cebus, operatorname, however, ursus, with,
# Nearest to after: six, in, before, as, when, was, seven, by,
# Nearest to more: less, most, futures, not, cardiomyopathy, wct, agouti, circ,
# Nearest to see: and, circ, thaler, seven, ursus, UNK, but, wct,
# Nearest to into: from, on, in, by, six, with, nine, to,
# Nearest to with: in, by, and, for, from, between, six, agouti,
# Nearest to six: five, seven, eight, four, nine, three, zero, two,
# Nearest to as: by, in, and, microcebus, agouti, circ, UNK, is,
# Nearest to however: but, and, which, that, circ, dasyprocta, ursus, although,
# Nearest to new: circ, microcebus, microsite, six, aba, UNK, operatorname, thaler,
# Nearest to at: in, on, michelob, from, five, operatorname, ursus, with,
# Nearest to there: it, they, he, zero, kapoor, which, this, six,
# Nearest to s: his, and, zero, operatorname, was, six, the, UNK,
# Average loss at step  92000 :  4.67243928194046
# Average loss at step  94000 :  4.72534086740017
# Average loss at step  96000 :  4.697424467682838
# Average loss at step  98000 :  4.597232312083245
# Average loss at step  100000 :  4.702773579955101
# Nearest to while: when, although, are, from, after, and, were, but,
# Nearest to only: cebus, kapoor, six, three, busan, it, circ, michelob,
# Nearest to known: such, used, aba, well, circ, operatorname, cebus, aeronautics,
# Nearest to during: in, upanija, kapoor, cebus, after, operatorname, with, at,
# Nearest to after: before, in, six, when, as, seven, was, five,
# Nearest to more: less, most, futures, not, agouti, cardiomyopathy, circ, michelob,
# Nearest to see: and, circ, seven, eight, six, thaler, four, ursus,
# Nearest to into: from, in, to, nine, on, by, six, with,
# Nearest to with: in, by, between, for, seven, from, six, and,
# Nearest to six: seven, eight, five, four, three, nine, two, zero,
# Nearest to as: by, agouti, is, microcebus, circ, for, cebus, six,
# Nearest to however: but, which, that, and, although, four, dasyprocta, circ,
# Nearest to new: microcebus, circ, six, aba, microsite, of, dn, operatorname,
# Nearest to at: in, on, michelob, from, five, ursus, with, operatorname,
# Nearest to there: it, he, they, which, this, kapoor, pontificia, zero,
# Nearest to s: his, zero, four, operatorname, eight, and, five, ursus,

# %%
# Step 6: Visualize the embeddings.

# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(
            label,
            xy=(x, y),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')

    plt.savefig(filename)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
        perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)

# %%
def k_most_similar_words(word, k):
    final_embeddings_distance_matrix = euclidean_distances([final_embeddings[dictionary[word]]], final_embeddings)

    final_embeddings_distance_matrix = np.argsort(final_embeddings_distance_matrix[0])[:21]
    final_embeddings_distance_matrix = np.delete(final_embeddings_distance_matrix, 0)

    for index in final_embeddings_distance_matrix:
        print(reverse_dictionary[index])

# %%
k_most_similar_words('is', 20)
# Out:
# was
# are
# has
# be
# kapoor
# operatorname
# as
# ursus
# thaler
# were
# wct
# eight
# agouti
# microcebus
# circ
# gollancz
# dasyprocta
# six
# nine
# by

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = [['this', 'is', 'a', 'test']]
candidate = ['this', 'is', 'a', 'test']
score = sentence_bleu(reference, candidate)
print(score)
# Out:
# 1.0
